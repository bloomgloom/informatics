# %% [markdown]
# * 학년:
# * 반:
# * 번호:
# * 이름:

# %% [markdown]
# # 선택 활동 6: 당신의 취향에 맞는 카페 음료 추천하기
#
# 카페의 수많은 메뉴 중에서 고객의 취향을 고려해 음료를 추천하려면 어떻게 해야 할까? 군집 모델을 이용해 사용자 취향에 맞는 음료를 추천해 보자.

# %% [markdown]
# ## 단계 0: 준비 (라이브러리 설치)

# %%
import importlib, sys, subprocess

packages = [
    ('pandas', 'pandas'),
    ('numpy', 'numpy'),
    ('sklearn', 'scikit-learn'),
    ('matplotlib.pyplot', 'matplotlib'),
    ('seaborn', 'seaborn'),
]

for module_name, pip_name in packages:
    try:
        importlib.import_module(module_name)
    except ModuleNotFoundError:
        subprocess.run([sys.executable, '-m', 'pip', 'install', '-q', pip_name])

from sklearn import set_config
set_config(display="text")

print('라이브러리 준비 완료')

# %% [markdown]
# ## 단계 1: 문제 정의하기
#
# 설탕과 카페인을 이용해 군집 모델을 생성해 음료를 추천해 보자.

# %% [markdown]
# ## 단계 2: 데이터 수집 및 전처리하기
#
# ### (1) 데이터 수집하기
#
# 아래 주어진 링크에 들어가서 우리나라 수많은 카페 매장에서 제공하는 음료 성분 데이터를 수집해 스프레드시트 파일로 저장한 `caffe_menu.csv`를 다운로드한다.
#
# https://bit.ly/caffe_menu
#
# ### (2) 데이터 전처리하기
#
# ① 군집 모델에 사용할 특징으로 설탕(sugars(g)), 카페인(caffeine(mg))을 선택해 데이터 프레임(data)을 생성한다.
#
# 1. `pandas` 패키지를 불러온다.
# 2. `caffe_menu.csv` 파일을 불러와 데이터 프레임 `df`를 생성한다.
# 3. `sugars(g)`, `caffeine(mg)` 열을 선택해 데이터 프레임 `data`를 생성한다.

# %% [markdown]
# **❓ 확인하기**
#
# - 군집 모델의 특징으로 선택한 두 열은 무엇인가?  → ( )
# - 군집 모델에는 정답에 해당하는 타깃이 필요한가?  → ( )

# %% [markdown]
# ② 최소-최대 정규화(MinMaxScaler)를 이용해 0~1 사이 값으로 정규화한다.
#
# 1. `MinMaxScaler`를 불러온다.
# 2. 최소-최대 정규화 객체를 생성해 `scaler`에 저장한다.
# 3. `fit_transform()`으로 `data`를 정규화해 `data_scaled`에 저장한다.

# %%
# MinMaxScaler 객체 생성
# data 정규화하기

# %% [markdown]
# **❓ 확인하기**
#
# - 정규화 후 두 특징의 값은 어떤 범위로 바뀌었는가?  → ( ) ~ ( )
# - 설탕(g)과 카페인(mg)을 같은 범위로 맞추는 이유는 무엇인가?
#
#   → ( )

# %% [markdown]
# ## 단계 3: 모델 생성하기
#
# ① k-평균 군집화 알고리즘으로 군집 모델을 생성한다.
#
# 1. `KMeans`를 불러온다.
# 2. 군집 개수가 4인 k-평균 군집 모델을 생성해 `model`에 저장한다.
# 3. `fit()`으로 정규화한 데이터 `data_scaled`를 학습시킨다.
# 4. 군집 결과를 `df`의 `cluster` 열에 저장한다.

# %%
# k = 4인 군집 모델 생성하기
# 군집 모델 학습하기
# 군집 결과 df[‘cluster’]에 저장하기

# %% [markdown]
# **❓ 확인하기**
#
# - 이 모델은 어떤 기준으로 음료를 4개 군집으로 나누는가?
#
#   → ( )
# - 군집 번호는 음료의 좋고 나쁨이나 순위를 뜻하는가?  → ( )

# %% [markdown]
# ② 군집에 어떤 음료가 속하는지 찾아본다.
#
# 1. `cluster` 열의 값이 0인 행만 선택한다.
#
#    (1) `df['열 이름'] == 값`의 형식으로 각 행이 조건을 만족하는지 확인한다.
#
#    (2) 만든 조건을 `df[조건]`의 형식으로 데이터 프레임에 적용한다.
#
# 2. 선택한 행에서 `name` 열을 추출한다.
#
# > 군집 번호를 0~3으로 변경하며 군집에 어떤 음료가 속했는지 확인해 보자.

# %%
# 군집 0번에 속하는 음료 이름

# %% [markdown]
# **❓ 확인하기**
#
# - 0~3번 군집은 각각 어떤 특징을 가진 음료들로 이루어져 있는가?  → ( )
# - 군집 번호는 실행할 때마다 같은 종류의 음료를 뜻하는가?  → ( )

# %% [markdown]
# ## 다른 속성으로도 군집 모델을 만들어 보자.
