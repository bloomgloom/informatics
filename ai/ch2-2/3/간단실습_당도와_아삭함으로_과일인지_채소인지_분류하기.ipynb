# %% [markdown]
# * 학년:
# * 반:
# * 번호:
# * 이름:

# %% [markdown]
# # 간단! 실습: 당도와 아삭함으로 과일인지 채소인지 분류하기

# %% [markdown]
# **단계별 처리 과정**
#
# | 단계 1 | 단계 2 | 단계 3 | 단계 4 |
# |:---:|:---:|:---:|:---:|
# | 문제 정의 | 데이터 수집 및 전처리 | 모델 생성 | 모델 평가 |

# %% [markdown]
# ## 단계 0: 준비 (라이브러리 설치)

# %%
import importlib, sys, subprocess

packages = [
    ('pandas', 'pandas'),
    ('numpy', 'numpy'),
    ('sklearn', 'scikit-learn'),
    ('matplotlib.pyplot', 'matplotlib'),
    ('seaborn', 'seaborn'),
]

for module_name, pip_name in packages:
    try:
        importlib.import_module(module_name)
    except ModuleNotFoundError:
        subprocess.run([sys.executable, '-m', 'pip', 'install', '-q', pip_name])

from sklearn import set_config
set_config(display="text")

print('라이브러리 준비 완료')

# %% [markdown]
# ## 단계 1 문제 정의하기
#
# 당도와 아삭함으로 과일인지 채소인지 분류해 보자.

# %% [markdown]
# ## 단계 2 데이터 수집 및 전처리하기
#
# ① 주어진 링크에서 `food.csv`를 다운로드한다.
#
# https://bit.ly/food_data

# %% [markdown]
# ② `food.csv` 파일을 업로드한 후, 데이터 프레임(df)을 생성한다.

# %% [markdown]
# **❓ 확인하기**
#
# - 이 데이터에서 식품의 특징을 수치로 나타낸 속성은 무엇인가?  → ( )
# - 과일과 채소 중 무엇인지 나타내는 속성은 무엇인가?  → ( )
# - 당도와 아삭함만으로 과일과 채소를 구분할 수 있을지 확인하려면 어떤 그래프를 그려 보면 좋을까?
#
#   → ( )

# %% [markdown]
# ③ 데이터를 산점도로 표현한다.

# %% [markdown]
# **❓ 확인하기**
#
# - 산점도에서 과일(fruit)과 채소(vegetable)는 완전히 나뉘는가?  → ( )
# - 당도가 높고 아삭함이 낮은 식품은 주로 어떤 class인가?  → ( )
# - 새로운 식품을 분류할 때 주변의 가까운 식품들을 참고하는 방법을 사용할 수 있을까? 그 이유는 무엇인가?
#
#   → ( )

# %% [markdown]
# ④ 특징(X)은 당도(sweet), 아삭함(crunchy)으로, 타깃(target)은 클래스(class)로 선정한다.

# %%
# 특징(X) 선정하기
# 타깃(y) 선정하기

# %% [markdown]
# **❓ 확인하기**
#
# - 모델이 분류의 근거로 사용할 특징 X는 무엇인가?  → ( )
# - 모델이 맞혀야 할 정답인 타깃 y는 무엇인가?  → ( )
# - 식품 이름(`ingredient`)을 특징 X에서 제외한 이유는 무엇인가?
#
#   → ( )

# %% [markdown]
# ## 단계 3 모델 생성하기
#
# 최근접 이웃 알고리즘인 KNeighborsClassifier를 이용해 분류 모델을 생성한다.

# %%
# 최근접 이웃 구현하기(k=3)
# 분류 모델 학습시키기

# %% [markdown]
# **❓ 확인하기**
#
# - `n_neighbors=3`은 새로운 식품을 분류할 때 무엇을 뜻하는가?
#
#   → ( )

# %% [markdown]
# ## 단계 4 모델 평가하기
#
# 당도(2), 아삭함(5)일 때, 과일(fruit)인지 채소(vegetable)인지 분류를 예측한다.

# %%
# 분류 모델로 예측하기

# %% [markdown]
# **❓ 확인하기**
#
# - 당도 2, 아삭함 5인 식품은 무엇으로 예측되었는가?  → ( )
# - 예측 결과를 산점도에서 관찰한 경향과 연결해 설명해 보자.
#
#   → ( )

# %% [markdown]
# ## 🏁 마무리: 스스로 정리하기
#
# 1. k=3은 무엇을 뜻하는가?
#
#    →
#
# 2. 당도 2, 아삭함 5인 식품은 무엇으로 분류되는가?
#
#    →
#
# 3. 이 식품이 그렇게 분류된 이유를, 산점도에서 가장 가까운 이웃 3개를 찾아 설명해 보자.
#
#    →
