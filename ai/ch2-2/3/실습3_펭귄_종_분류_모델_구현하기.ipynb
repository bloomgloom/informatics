# %% [markdown]
# * 학년:
# * 반:
# * 번호:
# * 이름:

# %% [markdown]
# # 실습 3: 펭귄 종 분류 모델 구현하기
#
# 부리 길이·부리 깊이·날개 길이로 아델리, 턱끈, 젠투펭귄을 분류하는 결정트리 모델을 구현해 보자.

# %% [markdown]
# **단계별 처리 과정**
#
# | 단계 1 | 단계 2 | 단계 3 | 단계 4 |
# |:---:|:---:|:---:|:---:|
# | 문제 정의 | 데이터 수집 및 전처리 | 모델 생성 | 모델 평가 |

# %% [markdown]
# ## 단계 0: 준비 (라이브러리 설치)

# %%
import importlib, sys, subprocess
packages=[('pandas','pandas'),('matplotlib','matplotlib'),('seaborn','seaborn'),('sklearn','scikit-learn')]
for module,pip_name in packages:
    try: importlib.import_module(module)
    except ModuleNotFoundError: subprocess.run([sys.executable,'-m','pip','install','-q',pip_name], check=True)

from sklearn import set_config
set_config(display="text")

print('라이브러리 준비 완료')

# %% [markdown]
# ## 단계 1: 문제 정의하기
#
# **펭귄의 특징값으로 펭귄 종을 분류해 보자.**

# %% [markdown]
# ## 단계 2: 데이터 수집 및 전처리하기

# %% [markdown]
# **💡 복습: `read_csv()`와 `info()`**
#
# `pd.read_csv()`로 파일을 읽고 `df.info()`로 열, 자료형, 결측치 여부를 확인한다.

# %%
# pandas로 penguins_size.csv를 불러와 df에 저장하고 정보 확인하기

# %% [markdown]
# **❓ 확인하기**
#
# - 이 데이터에는 데이터가 모두 몇 개 있는가?  → (　　　) 개
# - 결측치가 있는 속성은 무엇이고, 각각 몇 개인가?
#
#   → (　　　　　　　　　　　　　　　　　　　　　　)

# %% [markdown]
# **💡 복습: 결측치 처리**
#
# - `df.isnull().sum()`은 열별 결측치 수를 센다.
# - `df.dropna(axis=0, inplace=True)`는 결측치가 있는 행을 원본에서 삭제한다.

# %%
# 열별 결측치 개수를 확인한 뒤 결측치가 있는 행 삭제하기

# %% [markdown]
# **❓ 확인하기**
#
# - 결측치를 삭제한 후 데이터는 몇 개로 줄었는가?  → (　　　) 개

# %% [markdown]
# **💡 참고: 분류의 특징과 타깃**
#
# 펭귄의 세 신체 길이를 특징 X로, 종(`species`)을 타깃 y로 선택한다. 여러 특징은 `df[[...]]`로 선택한다.

# %%
# 부리 길이, 부리 깊이, 날개 길이를 X로, species를 y로 선정하기

# %% [markdown]
# **❓ 확인하기**
#
# - 특징 X로 선택한 속성은 몇 개인가?  → (　) 개
# - 타깃 y인 species에는 어떤 값이 있는가?
#
#   → (　　　　　　　　　　　　　　　　　　　　　　)

# %% [markdown]
# **💡 새 매개 변수: `stratify=y`**
#
# - `train_test_split()`은 회귀 실습에서 사용한 데이터 분할 함수이다.
# - 분류에서는 `stratify=y`를 지정하면 각 펭귄 종의 비율이 훈련·테스트 데이터에 비슷하게 유지된다.
# - `random_state=42`는 실행할 때마다 같은 분할을 재현한다.

# %%
# 데이터를 훈련 70%, 테스트 30%로 계층 분할하기(random_state=42)

# %% [markdown]
# **❓ 확인하기**
#
# - 훈련 데이터와 테스트 데이터는 각각 몇 개인가?  → 훈련 (　　　) 개 · 테스트 (　　　) 개
# - `stratify=y`를 사용하면 어떤 효과가 있는가?
#
#   → (　　　　　　　　　　　　　　　　　　　　　　)

# %% [markdown]
# ## 단계 3: 모델 생성하기
#
# **💡 새 API: `DecisionTreeClassifier`**
#
# - `DecisionTreeClassifier()`는 특징값에 대한 질문을 이어 붙이는 분류 모델을 만든다.
# - `dt.fit(X_train, y_train)`은 훈련 데이터로 분할 기준을 학습한다.
# - `dt.score(X, y)`는 맞힌 비율인 정확도를 반환한다.

# %%
# DecisionTreeClassifier 모델(dt)을 만들고 훈련 데이터로 학습하기(random_state=42)

# %% [markdown]
# **❓ 확인하기**
#
# - 훈련 데이터에 대한 정확도(`dt.score(X_train, y_train)`)는 약 얼마인가?  → (　　　　)

# %% [markdown]
# **💡 새 API: `plot_tree()`**
#
# - `plot_tree(dt, feature_names=X.columns, max_depth=2, filled=True)`로 결정트리의 위쪽 2단계를 그린다.
# - `feature_names`는 질문에 실제 특징 이름을 표시하고, `filled=True`는 예측 클래스에 따라 노드 색을 칠한다.

# %%
# plot_tree로 최대 깊이 2까지 결정트리 시각화하기

# %% [markdown]
# **❓ 확인하기**
#
# - 트리의 맨 위(루트 노드)에서 가장 먼저 사용한 특징은 무엇인가?  → (　　　　　　　　　　　　　　　　)
# - 그 특징의 기준값(threshold)은 대략 얼마인가?  → (　　　　)

# %% [markdown]
# ## 단계 4: 모델 평가하기

# %%
# 테스트 데이터를 예측하고 정확도 구하기

# %% [markdown]
# **❓ 확인하기**
#
# - 테스트 데이터에 대한 정확도는 약 얼마인가?  → (　　　　)
# - 훈련 정확도와 테스트 정확도를 비교해 보자. 차이가 있는가?
#
#   → (　　　　　　　　　　　　　　　　　　　　　　)

# %% [markdown]
# ## 🏁 마무리
#
# 1. 루트 노드에서 가장 먼저 사용한 특징은 무엇인가?
#
#    →
#
# 2. 훈련 정확도와 테스트 정확도가 다른 이유는 무엇인가?
#
#    →
#
# 3. 이 모델을 실제 생태 조사에 활용한다면 어떤 점에 주의해야 할까?
#
#    →
