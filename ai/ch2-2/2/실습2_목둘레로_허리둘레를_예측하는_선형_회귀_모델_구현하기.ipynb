# %% [markdown]
# * 학년:
# * 반:
# * 번호:
# * 이름:

# %% [markdown]
# # 실습 2: 목둘레로 허리둘레를 예측하는 선형 회귀 모델 구현하기
#
# > 목둘레로 내 허리 치수에 잘 맞는 청바지를 고를 수 있다고 한다. 신체 치수를 이용해 허리둘레를 예측하는 선형 회귀 모델을 구현해 보자.

# %% [markdown]
# **단계별 처리 과정**
#
# | 단계 1 | 단계 2 | 단계 3 | 단계 4 |
# |:---:|:---:|:---:|:---:|
# | 문제 정의 | 데이터 수집 및 전처리 | 모델 생성 | 모델 평가 |

# %% [markdown]
# ## 단계 0: 준비 (라이브러리 설치)

# %%
import importlib, sys, subprocess

packages = [
    ('pandas', 'pandas'),
    ('numpy', 'numpy'),
    ('matplotlib', 'matplotlib'),
    ('sklearn', 'scikit-learn'),
]

for module_name, pip_name in packages:
    try:
        importlib.import_module(module_name)
    except ModuleNotFoundError:
        subprocess.run([sys.executable, '-m', 'pip', 'install', '-q', pip_name])

print('라이브러리 준비 완료')

# %% [markdown]
# ## 단계 1: 문제 정의하기
#
# **신체 치수를 알면 허리둘레를 예측할 수 있을까?**

# %% [markdown]
# ## 단계 2: 데이터 수집 및 전처리하기
#
# ### ① 데이터 수집하기
#
# 주어진 링크에서 `jeans.csv`를 다운로드한다.
#
# - https://bit.ly/jeans_data
#
# > `jeans.csv`는 국방부 공군 신체 측정 정보에서 목둘레, 몸무게, 엉덩이둘레, 허리둘레 열만 남기고 이상치를 제거한 파일이다. 공군 데이터만을 사용하므로 모든 경우를 일반화할 수 없음에 유의한다.

# %% [markdown]
# `jeans.csv` 파일을 업로드하고 데이터 프레임(df)을 생성한다.

# %%
# pandas 라이브러리 가져오기
# jeans.csv를 불러와 데이터 프레임(df) 생성하기
# 데이터 프레임 5행 보여 주기

# %% [markdown]
# **❓ 확인하기**
#
# - 이 데이터에는 몇 개의 속성(열)이 있는가?  → (　　) 개
# - 각 속성은 어떤 신체 치수를 나타내는가?
#
#   → `neck`(　　　　) · `weight`(　　　　) · `heap`(　　　　) · `waist`(　　　　)

# %% [markdown]
# ### ② 데이터 전처리하기
#
# #### 독립 변수와 종속 변수 선정하기
#
# 목둘레로 허리둘레를 예측하는 단순 선형 회귀 모델을 만든다.
#
# - 독립 변수(X): 목둘레(`neck`)
# - 종속 변수(y): 허리둘레(`waist`)
#
# > `reshape(-1, 1)`은 열의 수를 1로 설정하여 2차원 배열로 변환한다. `-1`은 배열의 크기를 자동으로 조절한다.

# %%
# numpy 라이브러리 가져오기
# 목둘레(neck)를 독립 변수 X로 선정하고 2차원 배열로 변환하기
# 허리둘레(waist)를 종속 변수 y로 선정하기

# %% [markdown]
# #### 훈련 데이터와 테스트 데이터 분할하기
#
# 전체 데이터에서 훈련 데이터는 70%, 테스트 데이터는 30%로 분할한다.
#
# - `train_test_split()`: 데이터를 훈련 데이터와 테스트 데이터로 분할한다.
# - `test_size=0.3`: 전체의 30%를 테스트 데이터로 사용한다.
# - `random_state=42`: 동일한 무작위 분할 결과를 얻기 위한 시드값이다.

# %%
# train_test_split 가져오기
# X와 y를 훈련 데이터 70%, 테스트 데이터 30%로 분할하기
# X_train, X_test, y_train, y_test의 모양 출력하기

# %% [markdown]
# **❓ 확인하기**
#
# - `X_train`은 몇 개의 데이터로 이루어져 있는가?  → (　　　) 개
# - `X_test`는 몇 개의 데이터로 이루어져 있는가?  → (　　　) 개
# - `X_train`, `X_test`, `y_train`, `y_test`는 각각 무엇을 나타내는가?
#
#   → (　　　　　　　　　　　　　　　　　　　　　　)
# - 훈련 데이터가 테스트 데이터보다 많은 이유는 무엇일까?
#
#   → (　　　　　　　　　　　　　　　　　　　　　　)

# %% [markdown]
# ## 단계 3: 모델 생성하기
#
# ### ① 기계학습 유형과 알고리즘 선정하기
#
# 연속적인 값을 예측하므로 지도학습의 선형 회귀 모델을 사용한다. 독립 변수가 하나이므로 단순 선형 회귀에 해당한다.
#
# ### ② 모델 학습하기
#
# `LinearRegression`으로 선형 회귀 모델(`model`)을 생성하고, 훈련 데이터로 학습시킨다.

# %%
# LinearRegression 가져오기
# 선형 회귀 모델(model) 생성하기
# X_train과 y_train으로 모델 학습하기

# %% [markdown]
# 모델의 회귀계수와 절편을 구한다.
#
# - `model.coef_`: 모델의 회귀계수
# - `model.intercept_`: 모델의 절편

# %%
# 모델의 회귀계수와 절편 출력하기

# %% [markdown]
# **❓ 확인하기**
#
# - 이 모델의 회귀계수(a)는 약 얼마인가?  → (　　　　)
# - 절편(b)은 약 얼마인가?  → (　　　　)
# - 회귀계수와 절편을 이용하여 회귀식을 세워 보자.
#
#   → ŷ = (　　　　) × x + (　　　　)

# %% [markdown]
# 훈련 데이터에 대한 모델의 결정계수(R²)를 구한다. `model.score()`는 모델의 성능을 평가한다.

# %%
# X_train과 y_train을 이용해 모델의 결정계수 구하기

# %% [markdown]
# **❓ 확인하기**
#
# - 훈련 데이터에 대한 결정계수(R²)는 약 얼마인가?  → (　　　　)

# %% [markdown]
# ## 단계 4: 모델 평가하기
#
# ### ① 테스트 데이터로 성능 평가하기

# %%
# X_test와 y_test를 이용해 모델의 성능 평가하기

# %% [markdown]
# **❓ 확인하기**
#
# - 테스트 데이터에 대한 결정계수(R²)는 약 얼마인가?  → (　　　　)
# - 훈련 데이터와 테스트 데이터의 결정계수를 비교해 보자. 어느 쪽이 더 높은가?  → (　　　　　　)
# - 결정계수는 0~1 사이의 값으로, 1에 가까울수록 무엇을 의미하는가?
#
#   → (　　　　　　　　　　　　　　　　　　　　　　)
# - 이 모델은 목둘레만으로 허리둘레를 어느 정도 설명할 수 있는가? (잘 설명한다 / 어느 정도 설명한다 / 거의 설명하지 못한다)
#
#   → (　　　　　　　　　　)

# %% [markdown]
# ### ② 테스트 데이터로 예측하기
#
# `model.predict()`는 새로운 데이터에 대한 예측을 수행한다. `predictions[:5]`와 `y_test[:5]`를 비교해 보자.

# %%
# X_test로 예측하고 predictions에 저장하기
# 처음 5개의 예측값 출력하기
# 처음 5개의 테스트 결과값 출력하기

# %% [markdown]
# **❓ 확인하기**
#
# - 처음 5개의 예측값과 실제 값을 비교해 보자. 비슷한가, 차이가 큰가?
#
#   → (　　　　　　　　　　　　　　　　　　　　　　)

# %% [markdown]
# ### ③ 테스트 데이터와 예측값 시각화하기
#
# 테스트 데이터의 실제 값은 산점도로, 모델의 예측값은 선그래프로 표현한다.

# %%
# matplotlib.pyplot 가져오기
# X_test와 y_test를 파란색 산점도로 표시하기
# X_test와 predictions를 빨간색 선그래프로 표시하기
# x축을 neck, y축을 waist로 설정하기
# 그래프 보여 주기

# %% [markdown]
# **❓ 확인하기**
#
# - 파란 점(실제 값)과 빨간 선(예측값)이 얼마나 가까운가? 이를 통해 모델의 예측 성능을 평가해 보자.
#
#   → (　　　　　　　　　　　　　　　　　　　　　　)

# %% [markdown]
# ## 🏁 마무리: 스스로 정리하기
#
# 1. 이 모델의 독립 변수와 종속 변수는 무엇인가?
#
#    →
#
# 2. 회귀계수와 절편을 이용해 선형 회귀식을 써 보자.
#
#    →
#
# 3. 훈련 데이터와 테스트 데이터의 결정계수를 비교해 보자.
#
#    →
#
# 4. 공군 신체 측정 데이터로 만든 모델을 모든 사람에게 그대로 적용해도 될까? 그 이유를 써 보자.
#
#    →
