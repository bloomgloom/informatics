# %% [markdown]
# * 학년:
# * 반:
# * 번호:
# * 이름:

# %% [markdown]
# # 선택 활동 2: 다중 선형 회귀로 허리둘레를 예측해 보기
#
# 목둘레(`neck`), 몸무게(`weight`), 엉덩이둘레(`heap`)를 이용해 허리둘레(`waist`)를 예측하는 다중 선형 회귀 모델을 만들어 보자.

# %% [markdown]
# ## 단계 0: 준비 (라이브러리 설치)

# %%
import importlib, sys, subprocess

packages = [
    ('pandas', 'pandas'),
    ('numpy', 'numpy'),
    ('sklearn', 'scikit-learn'),
]

for module_name, pip_name in packages:
    try:
        importlib.import_module(module_name)
    except ModuleNotFoundError:
        subprocess.run([sys.executable, '-m', 'pip', 'install', '-q', pip_name])

from sklearn import set_config
set_config(display="text")

print('라이브러리 준비 완료')

# %% [markdown]
# ## 단계 2: 데이터 수집 및 전처리하기
#
# 실습 2에서 사용한 `jeans.csv` 파일을 업로드한다.

# %%
# pandas 라이브러리 가져오기
# jeans.csv를 불러와 데이터 프레임(df) 생성하기
# 데이터 프레임 5행 보여 주기

# %% [markdown]
# ### ① 독립 변수와 종속 변수 선정하기
#
# **💡 참고: `iloc`로 여러 개의 독립 변수 선택하기**
#
# ### 1. 필요한 열의 위치 확인하기
#
# - **문법 설명:** 데이터 프레임의 열은 왼쪽부터 0, 1, 2, … 번 인덱스를 가진다.
# - **이번 활동:** `df.head()` 결과에서 `neck`(0번), `weight`(1번), `heap`(2번) 열이 앞의 세 열에 있는지 확인한다.
#
# ### 2. `iloc`로 여러 열 한 번에 선택하기
#
# - **문법 설명:** `df.iloc[행 범위, 열 범위]`는 인덱스 번호로 필요한 행과 열을 선택한다. `:`는 해당 범위의 모든 값을 의미한다.
# - **사용 형식:** `df.iloc[:, 시작 열 : 끝 열]`
# - **이번 활동:** 모든 행에서 0~2번 열을 선택하도록 `df.iloc[:, :3]`을 사용한다. `:3`은 0번부터 2번 열까지를 뜻하며, 3번 열(`waist`)은 포함하지 않는다.
#
# ### 3. 배열 형태로 변환하기
#
# - **문법 설명:** `.values`는 선택한 데이터 프레임을 계산에 사용할 수 있는 배열 형태로 바꾼다.
# - **이번 활동:** `df.iloc[:, :3]` 뒤에 `.values`를 붙인다.
#
# ### 4. 독립 변수·종속 변수에 저장하기
#
# - **문법 설명:** `변수 이름 = 계산한 결과`의 형태로 결과를 저장한다.
# - **이번 활동:** 3번의 결과를 독립 변수 `X`에 저장한다. 종속 변수는 `df['waist']`를 `y`에 저장한다.

# %%
# neck, weight, heap 열을 독립 변수 X로 선정하기
# waist 열을 종속 변수 y로 선정하기

# %% [markdown]
# ### ② 훈련 데이터와 테스트 데이터 분할하기
#
# - `train_test_split(X, y, test_size=0.3, random_state=42)`는 전체 데이터의 70%를 훈련용, 30%를 테스트용으로 분할한다.
# - 분할 결과를 `X_train`, `X_test`, `y_train`, `y_test`에 저장한다.

# %%
# train_test_split 가져오기
# X와 y를 훈련 데이터 70%, 테스트 데이터 30%로 분할하기
# 훈련 데이터와 테스트 데이터의 모양 출력하기

# %% [markdown]
# **❓ 확인하기**
#
# - 훈련 데이터와 테스트 데이터는 각각 몇 개로 분할되었는가?  → 훈련 (　　　) 개 · 테스트 (　　　) 개
# - `X_train` 모양의 두 번째 숫자가 3인 이유는 무엇일까?
#
#   → (　　　　　　　　　　　　　　　　　　　　　　)

# %% [markdown]
# ## 단계 3: 모델 생성하기
#
# `LinearRegression()`으로 다중 선형 회귀 모델을 만들고, `fit()`으로 훈련 데이터를 학습시킨다.

# %%
# LinearRegression 가져오기
# 다중 선형 회귀 모델(model) 생성하기
# X_train과 y_train으로 모델 학습하기
# 모델의 회귀계수와 절편 출력하기

# %% [markdown]
# **❓ 확인하기**
#
# - `neck`, `weight`, `heap`의 회귀계수는 각각 얼마인가?
#
#   → neck (　　　　) · weight (　　　　) · heap (　　　　)
# - 회귀계수의 크기(절댓값)를 비교했을 때 허리둘레에 가장 큰 영향을 미치는 변수는 무엇인가?  → (　　　　)
#
# > 단, 속성별 단위와 범위가 다르면 회귀계수의 절대값만으로 영향력을 단정하기 어렵다.

# %% [markdown]
# ## 단계 4: 모델 평가하기
#
# 테스트 데이터로 다중 선형 회귀 모델의 결정계수를 구하고, 예측값과 실제 값을 비교한다.

# %%
# X_test와 y_test를 이용해 모델의 결정계수 출력하기
# X_test로 예측하고 predictions에 저장하기
# 처음 5개의 예측 결과 출력하기
# 처음 5개의 테스트 결과 출력하기

# %% [markdown]
# **❓ 확인하기**
#
# - 테스트 데이터에 대한 결정계수(R²)는 약 얼마인가?  → (　　　　)
# - 실습 2의 단순 선형 회귀 모델(목둘레만 사용) 결정계수는 약 0.71이었다. 다중 회귀 모델과 비교했을 때 어느 쪽 성능이 더 좋은가?  → (　　　　　　)
# - 예측 결과와 테스트 결과는 어느 정도 비슷한가?
#
#   → (　　　　　　　　　　　　　　　　　　　　　　)

# %% [markdown]
# ## 🏁 마무리: 스스로 정리하기
#
# 1. 단순 선형 회귀와 다중 선형 회귀의 차이는 무엇인가?
#
#    →
#
# 2. 독립 변수를 세 개로 늘렸을 때 모델의 설명력은 어떻게 달라졌는가?
#
#    →
#
# 3. 이 모델의 한계나 사용할 때 주의할 점을 써 보자.
#
#    →
