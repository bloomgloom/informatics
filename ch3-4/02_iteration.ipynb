# %% [markdown]
# # 3. 반복문
#
# > 고등학교 정보(천재교육) Ⅲ. 알고리즘과 프로그래밍 · 04 제어 구조의 응용 (p.129~134)
#
# **이름:** __________ &nbsp;&nbsp; **학번:** __________

# %% [markdown]
# 프로그래밍에서 **반복문**은 특정 명령문을 반복해서 실행해야 할 때 사용한다.
#
# 예를 들어 놀이공원 회전목마를 자동으로 20바퀴 운행하는 프로그램을 작성하려면 어떻게 해야 할까?
#
# | 일반 명령 예 | 반복문 사용 예 |
# |---|---|
# | 회전목마 1번째 바퀴 운행하시오.<br>회전목마 2번째 바퀴 운행하시오.<br>⋯<br>회전목마 20번째 바퀴 운행하시오. | **회전목마를 20바퀴 운행하시오.**<br>(범위 + 반복할 명령) |

# %%
# 프로그래밍으로 반복문 작성하기

# %% [markdown]
# 1~100까지의 합도 명령문 100개를 나열하는 대신 반복문으로 간단하게 구할 수 있다. 반복문의 종류에는 **for문**, **while문** 등이 있다.

# %%
# 1부터 100까지의 합 구하기 (반복문 사용)
    # 덧셈 100번 하기 (t = t + a 와 같다)

# %% [markdown]
# ## 1️⃣ for문
#
# 주로 **범위를 정해 놓고** 특정 명령문을 반복하는 구조이다.
#
# | 형식 1 | 형식 2 | 형식 3 |
# |---|---|---|
# | `for 변수 in 리스트[값, 값, …] :` | `for 변수 in 문자열 :` | `for 변수 in range(시작값, 종룟값, 증감값) :` |
#
# > ⚠️ **주의하세요!**
# > - for문은 반복할 범위를 지정한 후 마지막에 반드시 **콜론(`:`)**을 입력해야 한다.
# > - for문에서 반복할 명령문들은 같은 위치의 **들여쓰기**를 한다.
#
# ### ⑴ 단순 for문
#
# 한 개의 for문을 사용하는 구조로 범위에 리스트나 문자열, `range( )` 함수를 사용할 수 있다.

# %%
# 예제 23. 리스트에 저장된 값들을 하나씩 출력해 보자.

# %%
# 예제 24. 문자를 하나씩 출력해 보자.

# %%
# 예제 25. 일정 범위의 숫자를 출력해 보자.

# %% [markdown]
# ### 📌 하나 더 알기 — range( ) 함수
#
# 데이터 범위를 한번에 지정할 수 있는 명령문으로 주로 for문과 함께 사용된다.
#
# > **형식** `range([시작값], 종룟값, [증감값])`
#
# - range( ) 함수 범위는 '시작값'에서 **'종룟값 전의 값'**까지 '증감값'만큼 변화된다.
# - '시작값'이나 '증감값'은 생략 가능하며, 이 경우 '시작값'은 0, '증감값'은 1이다.

# %%
# range( ) 사용 예 — 세 가지 모두 0, 1, 2를 출력한다.
# 사용 예1: range(시작값, 종룟값, 증감값)
# 사용 예2: range(시작값, 종룟값)
# 사용 예3: range(종룟값)

# %% [markdown]
# ### 타이머 만들기
#
# > 💡 **time.sleep( )** : 파이썬에서 일정 시간 동작을 정지시킬 때 사용하는 명령문이다.

# %%
# 예제 26. 초를 입력하여 0초가 될 때까지 줄어드는 타이머 프로그램을 만들어 보자.

# %% [markdown]
# ### 🙌 예제 27 (빈칸 완성)
#
# [실행 결과]를 참고하여 **구구단의 단을 입력하면 해당 구구단을 출력하는 프로그램**을 완성해 보자.
#
# ```
# 실행 결과
# 몇 단? 5
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# ⋯
# 5 * 9 = 45
# ```

# %%
# 예제 27 ✏️ 빈칸을 채워 보자.
d = int(input("몇 단? "))
for i in range(1,        ) :
    a = d * i
    print(                        )

# %% [markdown]
# ### ⑵ 중첩 for문
#
# for문 안에 **또 다른 for문이 포함된 구조**로 내부 for문이 끝나면 외부 for문을 실행한다.
#
# | 외부 for문 | 내부 for문 |
# |---|---|
# | i = 0 | j = 0, j = 1, j = 2 |
# | i = 1 | j = 0, j = 1, j = 2 |
#
# 외부 for문의 반복 1번마다 내부 for문의 반복 명령문이 전부 실행된다.

# %%
# 중첩 for문의 수행 과정
# i를 0~1까지 반복하기 (외부 for문)
    # j를 0~2까지 반복하기 (내부 for문)
        # i, j값 출력하기

# %%
# 예제 28. 구구단 2단부터 9단까지 출력해 보자.
# 외부 for문
    # 내부 for문

# %% [markdown]
# ### 예제 29 — 세트 메뉴 조합
#
# > **문제 상황**
# > - ○○놀이공원의 햄버거 가게는 팝콘과 음료를 조합하여 다양한 세트 메뉴를 제공하고 있다.
# > - 팝콘은 '기본', '카라멜', '어니언' 세 가지 종류가 있고, 음료는 '생수'와 '탄산음료' 두 가지 종류가 있다.

# %%
# 예제 29 ✏️ 중첩 반복문을 사용하여 모든 세트 메뉴 조합을 출력해 보자.
popcorn_options = ["기본", "카라멜", "어니언"]   # 팝콘과 음료의 옵션
drink_options = ["생수", "탄산음료"]
for popcorn in popcorn_options :   # 모든 세트 메뉴 조합 출력
    for drink in                :
        print(                                    )

# %% [markdown]
# ## 2️⃣ while문
#
# **조건식이 참인 동안만** 내부의 명령문을 반복해서 실행하고 조건식이 거짓이면 반복문을 벗어난다.
#
# ```python
# 변수 초기화
# while 조건식 :
#     반복 명령문
# ```
#
# > ⚠️ **주의하세요!**
# > - while문의 조건식에서 변수를 사용한다면 변수를 미리 **초기화**한다.
# > - while문 내부의 반복할 명령문은 같은 위치의 들여쓰기를 한다.

# %%
# 예제 30. while문으로 1부터 5까지 출력해 보자.
# 조건식 변수 초기화
# 조건식
    # a값 출력하기
    # a값을 1씩 증가하기

# %% [markdown]
# ### 🔥 도전
#
# 예제 30을 **for문으로** 표현해 보자.

# %%
# 도전 ✏️ 예제 30을 for문으로 표현해 보자.
for a in              :
    print(a)

# %% [markdown]
# ### 📌 하나 더 알기 — 무한 반복
#
# 특정 명령을 무한히 반복하여 실행하는 것을 말한다. 무한 반복은 while문의 조건식 대신 `True`나 `1`을 쓰거나 조건식 결괏값을 항상 참이 되게 하여 만들 수 있다. 무한 반복을 벗어나기 위해서는 강제 종료를 하거나 while 내부에 `break`문을 사용할 수 있다.
#
# ```python
# while True :        while 1 :
#     print("!")          print("!")
# ```
#
# ## 3️⃣ 반복문의 제어
#
# 반복문에서 프로그램의 흐름을 제어하기 위한 명령문으로 **break문**, **continue문** 등이 있다.
#
# ### ⑴ break문
#
# 반복문을 실행하다가 **강제로 반복문을 벗어나야 할 경우**에 사용한다.

# %%
# 예제 31. q 또는 Q를 입력하면 게임을 종료하고 반복문을 빠져나가는 프로그램
# 무한 반복
    # 'q' 또는 'Q'를 입력하면
        # '프로그램 나가기' 출력하기
        # while문 탈출하기

# %% [markdown]
# ### ⑵ continue문
#
# 반복문을 실행하다가 **특정 명령문을 건너뛰고 처음으로 돌아가서** 반복문을 계속 실행할 경우에 사용한다.

# %%
# 예제 32 ✏️ 1부터 100 사이의 자연수 중 5의 배수 합을 출력해 보자. (결과: 1050)
total = 0                  # total 변수를 0으로 초기화하기
for i in range(1, 101) :   # i 변숫값을 1부터 100까지 반복하기
    if              :      # i가 5의 배수가 아닌가?
        continue           # 5의 배수가 아니라면 for문으로 돌아가기
    total += i             # i가 5의 배수라면, total 변수에 i값 더하기
print(total)               # 반복문이 종료되면 total값 출력하기
