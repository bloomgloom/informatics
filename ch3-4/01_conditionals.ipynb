# %% [markdown]
# # 2. 조건문
#
# > 고등학교 정보(천재교육) Ⅲ. 알고리즘과 프로그래밍 · 04 제어 구조의 응용 (p.125~128)
#
# **이름:** __________ &nbsp;&nbsp; **학번:** __________

# %% [markdown]
# 우리는 생활 속에서 조건을 고려하여 많은 일을 결정한다. 프로그램에서도 주어진 조건에 따라 명령을 수행해야 하는데, 이러한 구문을 **조건문**이라고 한다.
#
# ## 1️⃣ 단순 조건문
#
# ### ⑴ if문
#
# 가장 단순한 형태의 조건문으로 **조건식의 결과가 참(True)일 때만** 특정 명령문을 실행한다.
#
# ```python
# if 조건식 :
#     명령문 1
# 명령문 2
# ```
#
# - 조건식이 참일 때만 명령문 1을 실행하고 명령문 2를 실행한다.
# - 조건식의 결과가 거짓이면 명령문 1은 실행하지 않고 명령문 2를 실행한다.
# - 명령문 2는 조건식의 결과와 상관없이 무조건 실행한다.
#
# > ⚠️ **들여쓰기** : 참일 때 실행되는 명령문들은 반드시 들여쓰기 해야 한다. 들여쓰기는 코드 블록을 구분하는 데 사용하며 프로그램 구조를 명확하게 만든다.

# %%
# 예제 19. 어린이 보호 구역은 최고 통행 속도가 30km이다.
# 입력받은 차량 속도가 30을 초과하면 '과속입니다.'라고 출력해 보자. (예: 34 입력)

# %% [markdown]
# ### 🙌 활동 18
#
# 놀이공원의 '더블스핀' 놀이기구는 **140cm 미만은 탈 수 없다.** 사용자의 키를 입력받아 '더블스핀' 놀이기구를 탈 수 있는지의 여부를 출력하는 프로그램을 작성해 보자.
#
# ```
# 실행 결과
# 키: 121.5
# 더블스핀 놀이기구 탑승 불가
# ```

# %%
# 활동 18 ✏️ 조건문을 완성해 보자.
height = float(input("키: "))
if              :
    print("더블스핀 놀이기구 탑승 불가")

# %% [markdown]
# ### ⑵ if~else문
#
# 조건식의 결과가 **참(True)일 때와 거짓(False)일 때 실행하는 명령문이 다른 구조**이다.
#
# ```python
# if 조건식 :
#     명령문 1
# else :
#     명령문 2
# ```
#
# - 조건식이 참이면 명령문 1을 실행하고 거짓이면 명령문 2를 실행한다.

# %%
# 예제 20. 일반 도로와 어린이 보호 구역에서 자동차가 달릴 수 있는 속도를 안내해 보자.
# 입력값이 'a'일 때: '어린이 보호 구역은 시속 30km입니다.' 출력
# 입력값이 'a'가 아닐 때: '일반 도로는 시속 50km입니다.' 출력

# %% [markdown]
# ### 🙌 활동 19
#
# 놀이공원 앱에서 나이를 입력하면 [처리 조건]에 따라 **입장권 가격을 출력하는 프로그램**을 완성해 보자.
#
# > **처리 조건 — 놀이공원 입장권의 가격**
# > - 어린이, 청소년(18세 이하): 40,000원
# > - 성인: 50,000원

# %%
# 활동 19 ✏️ 빈칸에 알맞은 조건문을 작성해 보자.
age = int(input("나이를 입력하세요."))

    print("입장권 가격은 40,000원입니다.")
else :
    print("입장권 가격은 50,000원입니다.")

# %% [markdown]
# ## 2️⃣ 중첩 조건문
#
# 조건문 안에 **또 다른 조건문을 포함**하는 구조이다.
#
# ```python
# if 조건식 1 :
#     if 조건식 2 :
#         명령문 1
#     else :
#         명령문 2
# else :
#     명령문 3
# ```
#
# - 조건식 1이 참일 때 조건식 2도 참이면 명령문 1을 실행한다.
# - 조건식 1은 참이고 조건식 2가 거짓이면 명령문 2를 실행한다.
# - 조건식 1이 거짓이면 명령문 3을 실행한다.
#
# > 💡 if문 안에 또 다른 if문이 들어갈 수 있고, else문 안에 또 다른 if문이 들어갈 수도 있다.

# %%
# 예제 21. 도로 종류를 입력하여 제한 속도를 알려 주는 프로그램을 작성해 보자.
# '고속 도로' 제한 속도는 100km/h, '일반 도로'는 50km/h
# '일반 도로'이면서 어린이 보호 구역이 있으면 제한 속도는 30km/h

# %% [markdown]
# ## 3️⃣ 다중 조건문
#
# 선택 사항이 **여러 개**일 경우 사용하는 조건문으로 여러 개의 조건식에 따라 명령을 다르게 실행할 경우 사용한다.
#
# ```python
# if 조건식 1 :
#     명령문 1
# elif 조건식 2 :
#     명령문 2
# else :
#     명령문 3
# ```
#
# - 조건식 1이 참이면 명령문 1을 실행하고 if문을 벗어난다.
# - 조건식 1이 거짓이면 elif문의 조건식 2를 비교하여 그 결과가 참이면 명령문 2를 실행하고 if문을 벗어난다.
# - 조건식 1과 조건식 2가 모두 거짓이면 명령문 3을 실행한다.
#
# > 💡 elif문에는 반드시 조건식이 있어야 하며, else문 없이 여러 개의 elif문으로 다중 조건문을 만들 수 있다.

# %%
# 예제 22. 시험 점수를 입력하여 해당하는 학점을 출력해 보자. (예: 75 입력 → B)
# 80점 이상: A / 60점 이상 80점 미만: B / 60점 미만: C

# %% [markdown]
# ### 🙌 활동 20
#
# 키에 따른 놀이기구의 [탑승 조건]에 따라 **놀이기구 탑승 가능 여부를 출력하는 프로그램**을 완성해 보자.
#
# > **탑승 조건**
# > - 100cm 미만: 탑승 불가
# > - 100cm 이상 130cm 미만: 보호자 동행 시 탑승 가능
# > - 130cm 이상 195cm 미만: 탑승 가능
# > - 195cm 이상: 탑승 불가
#
# ```
# 실행 결과
# 키: 127
# 보호자 동행 시 탑승 가능
# ```

# %%
# 활동 20 ✏️ 나머지 조건문을 완성해 보자.
height = int(input('키: '))
if height < 100 :
    print('탑승 불가')
